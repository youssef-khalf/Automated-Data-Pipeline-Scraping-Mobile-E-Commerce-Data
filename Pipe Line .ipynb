# %%
# !pip install selenium
# !pip install webdriver_manager
# !pip install aiohttp
# !pip install nest_asyncio
# !pip install azure-storage-blob
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.10/dist-packages (4.25.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.2)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.10/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: webdriver_manager in /usr/local/lib/python3.10/dist-packages (4.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (2.32.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (1.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from webdriver_manager) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->webdriver_manager) (2024.8.30)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (3.10.10)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.15.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (4.0.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp) (4.12.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp) (3.10)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp) (0.2.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: azure-storage-blob in /usr/local/lib/python3.10/dist-packages (12.23.1)
# Requirement already satisfied: azure-core>=1.30.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (1.31.0)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (43.0.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (4.12.2)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (0.7.2)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.30.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2024.8.30)

# %% [markdown]
# # Scraping

# %%
import logging
import aiohttp
from bs4 import BeautifulSoup
import asyncio
import nest_asyncio
import random
import requests
import pandas as pd
from tqdm import tqdm

# Apply the nest_asyncio fix for running nested event loops
nest_asyncio.apply()

logging.basicConfig(level=logging.INFO)


# --- Function to scrape product links ---
async def scrape_product_links(param: dict) -> list:
    first_page_url = param.get('first_page_url')
    base_url = param.get('base_url')

    product_links = []

    async with aiohttp.ClientSession() as session:
        # First page request
        async with session.get(first_page_url) as response:
            text = await response.text()
            soup = BeautifulSoup(text, 'html.parser')
            products = soup.find_all('div', class_='sc-19767e73-0 bwele')

            for product in products:
                link = product.find('a', href=True)['href']
                full_link = f"https://www.noon.com{link}"
                product_links.append(full_link)

        # Pagination loop for subsequent pages
        page = 2
        while True:
            url = base_url.format(page)
            async with session.get(url) as response:
                text = await response.text()
                soup = BeautifulSoup(text, 'html.parser')
                products = soup.find_all('div', class_='sc-19767e73-0 bwele')

                if not products:
                    break

                for product in products:
                    link = product.find('a', href=True)['href']
                    full_link = f"https://www.noon.com{link}"
                    product_links.append(full_link)

            page += 1

    return product_links  # Returning the list of product links


# --- Helper function for retries ---
async def fetch_with_retries(session, url, retries=3):
    for attempt in range(retries):
        try:
            async with session.get(url) as response:
                await asyncio.sleep(random.uniform(2, 7))  # To avoid being blocked by the server
                return await response.text()
        except Exception as e:
            logging.error(f"Error on attempt {attempt + 1} for {url}: {str(e)}")
            if attempt == retries - 1:
                raise  # Raise the exception if this was the last attempt


# --- Function to scrape product details ---
async def scrape_product_details(url: str) -> dict:
    async with aiohttp.ClientSession() as session:
        try:
            text = await fetch_with_retries(session, url)  # Retry logic added
            soup = BeautifulSoup(text, 'html.parser')

            # Extract the title
            title = soup.find('h1', class_='sc-a748f04d-17 bsHsUV').text.strip() if soup.find(
                'h1', class_='sc-a748f04d-17 bsHsUV') else 'N/A'

            # Extract the price
            price = soup.find('div', class_='priceNow').text.strip() if soup.find('div',
                                                                                class_='priceNow') else 'N/A'

            # Extract brand
            brand = soup.find('div', class_='sc-a748f04d-16 jLPVLQ').text.strip() if soup.find(
                'div', class_='sc-a748f04d-16 jLPVLQ') else 'N/A'

            # Extract rating
            rating = soup.find('div', class_='sc-9cb63f72-2 dGLdNc').text if soup.find(
                'div', class_='sc-9cb63f72-2 dGLdNc') else 'N/A'

            # Extract product image
            img_tags = soup.find_all('img')
            product_image = [
                img.get('src').split('?')[0] for img in img_tags
                if img.get('src') and img.get('src').startswith('https://f.nooncdn.com/') and img.get(
                    'src').endswith('width=240')
            ]

            # Extract the specifications table
            specifications = {}
            specs_table = soup.find('table').find('tbody').find_all('tr') if soup.find('table') else []

            for row in specs_table:
                header = row.find_all('td')[0].text.strip()
                value = row.find_all('td')[1].text.strip()
                specifications[header] = value

            # Add title, price, and other details to the specifications
            specifications.update({
                'Title': title,
                'Price': price,
                'Brand': brand,
                'Rating': rating,
                'Product Image': product_image,
                'Product Link': url
            })

            # Filter out products that have too many "N/A" fields
            if all(value == 'N/A' for value in [title, price, brand]):
                logging.warning(f"Incomplete data for product: {url}, skipping.")
                return None  # Skip this product if critical fields are missing

            return specifications

        except Exception as e:
            logging.error(f"Error fetching details from {url}: {str(e)}")
            return None  # Return None if there's an error


# --- Function to scrape multiple product details ---
async def scrape_multiple_products(urls: list) -> list:
    tasks = [scrape_product_details(url) for url in urls]  # Create a list of tasks for each URL
    results = await asyncio.gather(*tasks)  # Run them concurrently

    # Filter out any None results (products that were skipped)
    valid_results = [result for result in results if result]
    return valid_results


# --- Main integrated function ---
async def main(param: dict):
    # Step 1: Scrape product links
    product_links = await scrape_product_links(param)

    # Step 2: Scrape details for each product link
    product_details = await scrape_multiple_products(product_links)

    return product_details


# Function to run the entire scraping process
def main_function(req: dict):
    return asyncio.run(main(req))


# --- Example usage ---
if __name__ == "__main__":
    param = {
        'first_page_url': 'https://www.noon.com/egypt-en/electronics-and-mobiles/mobiles-and-accessories/mobiles-20905/eg-all-mobiles/?fisCarousel=true&fis_fbn=1&limit=50&sortby=popularity&sortdir=desc',  # Replace with actual first page URL
        'base_url': 'https://www.noon.com/egypt-en/electronics-and-mobiles/mobiles-and-accessories/mobiles-20905/eg-all-mobiles/?fisCarousel=true&fis_fbn=1&limit=50&page={}&sortby=popularity&sortdir=desc'  # Replace with actual pagination URL
    }

    # Run the scraper
    product_data = main_function(param)

    # Process the scraped data (e.g., store it in a file, analyze it, etc.)
    if product_data:
        df = pd.DataFrame(product_data)
        print(df.head())  # Display the first few rows of the DataFrame
        # ... (Add code for storing data or further analysis) ...
# Out:
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-a3-dual-sim-star-blue-4gb-ram-128gb-4g-middle-east-version/N70045122V/p/?o=e3b9c84370cbf38b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/mobile-105-black-4g/N70032875V/p/?o=a681ee499ae710ba, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-fold-6-dual-sim-silver-shadow-12gb-ram-256gb-5g-middle-east-version/N70085325V/p/?o=f379bb46bfd05dfe, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-pro-256gb-desert-titanium-5g-with-facetime-middle-east-version/N70105580V/p/?o=c4e517eed145a29b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/poco-f6-pro-dual-sim-black-12gb-ram-512gb-5g-global-version/N70089591V/p/?o=d168969b54556dba, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c63-dual-sim-jade-green-8gb-ram-256gb-4g-middle-east-version/N70086811V/p/?o=a17ff018b505e74a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-max-256gb-black-titanium-5g-with-facetime-middle-east-version/N53432493A/p/?o=a0c1eaa490d0eaba, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s23-dual-sim-mystery-white-8-8gb-ram-128gb-4g-middle-east-version/N53436925A/p/?o=e890e1bff5198bbf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c51-dual-sim-carbon-black-4gb-ram-128gb-4g-lte-international-version/N53426586A/p/?o=e64f02b51121fc4a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a55-dual-sim-awesome-lemon-8gb-ram-256gb-5g-middle-east-version/N70049934V/p/?o=e04567e01a00e8bc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-titanium-silver-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068556V/p/?o=e96c123a75371b5d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-sunrise-orange-12gb-ram-256gb-middle-east-version/N70019228V/p/?o=a0eb493dda0d56cd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/hot-40i-dual-sim-palm-blue-8-8gb-ram-256gb-4g-middle-east-version/N70024022V/p/?o=aeeaec00d461a76e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/smart-8-dual-sim-galaxy-white-4-4gb-ram-64gb-4g-middle-east-version/N70080020V/p/?o=ff17eb98d08b074f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-note-12-dual-sim-onyx-gray-8gb-ram-128gb-4g-global-version/N53364542A/p/?o=b2ee628e9f4d4ccb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-emerald-green-12gb-ram-256gb-middle-east-version/N70019227V/p/?o=c6a0a701df2f830a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/benco-e11-dual-sim-32mb-dark-blue/N48582854A/p/?o=d05bb37175c5ba0c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a60-dual-sim-8gb-ram-256gb-midnight-purple-middle-east-version/N70069381V/p/?o=e1e11f76fc06f72f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/mobile-urban-3-plus-blue-32gb-2gb-4g/ZC146CFE76D1B22FA7C25Z/p/?o=zc146cfe76d1b22fa7c25z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-midnight-black-12gb-ram-256gb-middle-east-version/N70019226V/p/?o=fba92887b0ca07da, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sim-yellow-6gb-ram-128gb-4g-lte-middle-east-version/N70030441V/p/?o=f73bc2f49758baad, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/2160-dual-sim-black-32mb-2g/N24420265A/p/?o=c435f958a6b6799e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-lurex-black-12-12gb-ram-256gb-4g-middle-east-version/N70063667V/p/?o=bdbb3a10b7c2f69b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-emerald-green-12gb-ram-256gb-middle-east-version/N70019227V/p/?o=c6a0a701df2f830a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a18-dual-sim-glowing-black-4gb-ram-64gb-4g-lte-middle-east-version/N70016184V/p/?o=a094d12ddccb940f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a3-dual-sim-sparkle-black-8gb-ram-256gb-4g-international-version/N70105569V/p/?o=ac0b4002f6964c1f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-flip-6-dual-sim-blue-12gb-ram-256gb-5g-with-galaxy-buds-3/N70106354V/p/?o=f156fee57964ab1c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13c-dual-sim-navy-blue-4gb-ram-128gb-4g/N70040316V/p/?o=ae29fb236404000c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-flip-6-single-sim-esim-blue-12gb-ram-256gb-5g-middle-east-version/N70085222V/p/?o=e1e2ac90730c3a4d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8a-dual-sim-midnight-black-8gb-ram-128gb-4g-lte-middle-east-version/N53386101A/p/?o=e0bb9d13ffd6e6ac, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/vivo-y17s-6gb-ram-128gb-storage-forest-green/N70025349V/p/?o=bfbda37a5124885c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a7-plus-dual-sim-mobile-16-gb-internal-memory-2gb-ram-3g-network-emerald-green/Z2E1E30CE0213D3B89F78Z/p/?o=z2e1e30ce0213d3b89f78z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-flip-6-single-sim-esim-mint-12gb-ram-256gb-5g-middle-east-version/N70085223V/p/?o=b7b304437ff8bf9b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c65-dual-sim-starlight-gold-8gb-ram-256gb-4g-middle-east-version/N70071976V/p/?o=e526ee50082facfe, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7b-dual-sim-6gb-ram-256gb-4g-flowing-silver-with-honor-x6-earbuds-white/N70070456V/p/?o=cd9c76eff4ef546b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a25-dual-sim-blue-black-6gb-ram-128gb-5g-middle-east-version/N70029341V/p/?o=e9d64d0a3e3c75cd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c67-dual-sim-black-rock-8gb-ram-256gb-4g-international-version/N70056576V/p/?o=ec4493ef22bbe6fa, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-azure-blue-4gb-ram-256gb-4g-middle-east-version/N70027156V/p/?o=a8cebf58df1d389f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-s24-ultra-dual-sim-titanium-black-12gb-ram-256gb-5g-international-version/N70036947V/p/?o=d2d362bd13754eff, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sim-blue-black-6gb-ram-128gb-4g-lte-international-version/N70065709V/p/?o=f8c157c3689bb8fb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c67-dual-sim-sunny-oasis-8gb-ram-128gb-4g-international-version/N70056577V/p/?o=b6d8f075d0a3e5bc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-12-dual-sim-sky-blue-8gb-ram-128gb-4g-global-version/N53414854A/p/?o=e05cb9d6ea9a551a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a05s-dual-sim-black-6gb-ram-128gb-4g-lte-middle-east-version-with-a-free-gift-25w-adapter-usb-c-super-fast-charging-travel-adapter-eu-plug/N70112942V/p/?o=fb4f4c3a2f9fb57f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/note-50-dual-sim-sky-blue-3gb-ram-64gb-4g-middle-east-version/N70060365V/p/?o=f38d64bf3892094e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-fold-6-single-sim-esim-navy-12gb-ram-256gb-5g-middle-east-version/N70085323V/p/?o=d837f867ba4730ec, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-glamorous-green-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068555V/p/?o=e0e4c2a30018f1eb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-sunrise-orange-12gb-ram-256gb-middle-east-version/N70019228V/p/?o=a0eb493dda0d56cd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-lurex-black-12-12gb-ram-256gb-4g-middle-east-version/N70063667V/p/?o=bdbb3a10b7c2f69b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/12-5g-dual-sim-woodland-green-8gb-ram-512gb-middle-east-version/N70059175V/p/?o=ef0a30193aef40fb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-flip-6-single-sim-esim-silver-shadow-12gb-ram-256gb-5g-middle-east-version/N70085224V/p/?o=d6d73cfb58ccce8e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s3-dual-sim-1-8-inches-display-1000mah-battery-32mb-32mb-gray/Z623F07046D555B744B33Z/p/?o=z623f07046d555b744b33z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-s24-ultra-dual-sim-titanium-violet-12gb-ram-256gb-5g-international-version/N70036949V/p/?o=deaadfc18b9f61cc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-note-13-pro-5g-12-gb-512-gb-fusion-black-indian-version/N70036049V/p/?o=f7554346e57cedaf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-glamorous-green-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068555V/p/?o=e0e4c2a30018f1eb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/honor-x9b-12gb-5g-smartphone-sunrise-orange-256-gb/N70027910V/p/?o=b107bcb1b5f8136d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a05s-dual-sim-silver-4gb-ram-128gb-4g-lte-middle-east-version/N70029363V/p/?o=f1e189ef8d4ea7ee, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sim-yellow-4gb-ram-128gb-4g-middle-east-version/N70029834V/p/?o=edccdae2b228b14a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-plus-128gb-blue-5g-with-facetime-international-version/N53432662A/p/?o=f55301f7b31081bf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-lurex-black-12-12gb-ram-256gb-4g-middle-east-version/N70063667V/p/?o=bdbb3a10b7c2f69b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7b-dual-sim-6gb-ram-256gb-4g-flowing-silver-with-honor-x6-earbuds-white/N70070456V/p/?o=cd9c76eff4ef546b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-pro-max-512gb-desert-titanium-5g-with-facetime-middle-east-version/N70105587V/p/?o=ed1fa7355ce2edef, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-a3-dual-sim-forest-green-3gb-ram-64gb-4g-middle-east-version/N70045125V/p/?o=d2169ace94b1a5fc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-titanium-silver-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068556V/p/?o=e96c123a75371b5d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-s23-ultra-5g-dual-sim-lavender-12gb-ram-256gb-middle-east-version/N53374477A/p/?o=b6c7ad7490dce55b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/kxd-m23-mobile-phone-32mb-32ram-black-with-big-battary-2500-work-up-10-days/Z00FEC06AA51EDB24E3AFZ/p/?o=z00fec06aa51edb24e3afz-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iku-a6-2022-32gb-rom-1gb-ram-2400mah-3g-network-dark-green/Z9A79B8A5C0400C320B61Z/p/?o=z9a79b8a5c0400c320b61z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/y18-4g-dual-sim-wave-aqua-4gb-ram-128gb-middle-east-version/N70104746V/p/?o=cb4f1f827fe1943a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-glamorous-green-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068555V/p/?o=e0e4c2a30018f1eb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-emerald-green-12gb-ram-256gb-middle-east-version/N70019227V/p/?o=c6a0a701df2f830a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a34-dual-sim-awesome-graphite-8gb-ram-256gb-5g-middle-east-version/N53389447A/p/?o=a417fe06e5da486c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-pro-max-256gb-white-titanium-5g-with-facetime-international-version/N70106233V/p/?o=cac57ad0dc273a0e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-a3-dual-sim-star-blue-4gb-ram-128gb-4g-global-version/N70052311V/p/?o=bc7219e1f718e8ea, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-pro-max-physical-dual-sim-256gb-desert-titanium-5g-without-facetime/N70106334V/p/?o=a68c083973c329cf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-titanium-silver-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068556V/p/?o=e96c123a75371b5d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x6a-dual-sim-sky-silver-4gb-ram-128gb-4g/N70022031V/p/?o=c36cb27f72645e2d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-note-13-dual-sim-ice-blue-8gb-ram-256gb-global-version/N70035008V/p/?o=c6fc2122c471861e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-silvery-white-12-12gb-ram-256gb-4g-middle-east-version/N70063665V/p/?o=ffb866ab3602c86a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/hot-30i-dual-sim-mirror-black-8gb-ram-128gb-4g-lte/N53419086A/p/?o=df0bdd5f3a7e6a2a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-midnight-black-12gb-ram-256gb-5g-with-honor-choice-earbuds-x5/N70045710V/p/?o=ed1fb982f67e661b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-azure-blue-4gb-ram-256gb-4g-middle-east-version/N70027156V/p/?o=a8cebf58df1d389f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a25-dual-sim-yellow-8gb-ram-256gb-5g-middle-east-version/N70029760V/p/?o=ac2cea7f8de2518d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-256gb-black-titanium-5g-with-facetime-middle-east-version/N53432477A/p/?o=f35c4cb5aa557a5e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13c-dual-sim-glacier-white-4gb-ram-128gb-4g/N70055566V/p/?o=dbf874390322424f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-128gb-pink-5g-with-facetime-international-version/N70106130V/p/?o=cdd17b0119c5448c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/poco-x6-pro-5g-dual-sim-grey-12gb-ram-512gb-5g-global-version/N70029840V/p/?o=ee09ddcf6d2f468c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-fold-6-dual-sim-silver-shadow-12gb-ram-256gb-5g-international-version/N70092360V/p/?o=f408049951e990ec, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/smart-7-hd-dual-sim-jade-white-2gb-ram-64gb-4g-lte/N53410732A/p/?o=b1f0a473b6c891ca, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/reno-11f-dual-sim-coral-purple-8gb-ram-256gb-5g-international-version/N70091658V/p/?o=e842332729295bfa, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-sunrise-orange-12gb-ram-256gb-middle-east-version/N70019228V/p/?o=a0eb493dda0d56cd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/11-pro-astral-black-dual-sim-8gb-ram-256gb-5g/N70025285V/p/?o=da54c366804c82bf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a3x-dual-sim-nebula-red-4gb-ram-64gb-4g-middle-east-version/N70114003V/p/?o=cc8bf33c0cd7fbcf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-starlish-black-4gb-ram-256gb-4g-middle-east-version/N70027157V/p/?o=c62cd10bae14348d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/reno-12f-5g-dual-sim-amber-orange-12gb-ram-256gb-middle-east-version/N70094404V/p/?o=f85934c8917c04dc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-max-256gb-white-titanium-5g-with-facetime-middle-east-version/N53432479A/p/?o=caedb4f5343f533e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-max-1tb-natural-titanium-5g-with-facetime-international-version/N53432595A/p/?o=e44eaf384b8f886f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/reno11-f-5g-dual-sim-palm-green-8gb-ram-256gb-international-version/N70059055V/p/?o=d3e0a52d8a57c43b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x6a-dual-sim-sky-silver-4gb-ram-128gb-4g/N70022031V/p/?o=c36cb27f72645e2d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/12-5g-dual-sim-twilight-purple-8gb-ram-512gb-middle-east-version/N70059174V/p/?o=f3fb248fd48f827a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-starlish-black-4gb-ram-256gb-4g-middle-east-version/N70027157V/p/?o=c62cd10bae14348d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/gt6-5g-dual-sim-fluid-silver-12gb-ram-256gb-5g-international-version/N70087084V/p/?o=fe4fd63c56f641de, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/gt6-dual-sim-razor-green-16-12gb-ram-512gb-5g-middle-east-version/N70085257V/p/?o=cc95b855f21792be, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8a-dual-sim-midnight-black-8gb-ram-128gb-4g-lte-middle-east-version/N53386101A/p/?o=e0bb9d13ffd6e6ac, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a18-dual-sim-glowing-black-4gb-ram-128-gb-4g-global-version/N70073493V/p/?o=eae7b8903a73c58c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-midnight-black-12gb-ram-256gb-middle-east-version/N70019226V/p/?o=fba92887b0ca07da, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a58-dual-sim-verde-6gb-ram-128gb-4g-international-version/N70052020V/p/?o=c0e8fcd125f0632c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-physical-dual-sim-256gb-natural-titanium-5g-without-facetime/N53433251A/p/?o=d9a5f5ab16781acf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-sunrise-orange-12gb-ram-256gb-middle-east-version/N70019228V/p/?o=a0eb493dda0d56cd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x6a-dual-sim-cyan-lake-4gb-128gb-4g/N70022030V/p/?o=d65300a54f3d09cc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/v90-dual-sim-fog-grey-4gb-3gb-ram-128gb-middle-east-version/N70017842V/p/?o=b417872aeca8fdcd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-a3-dual-sim-star-blue-3gb-ram-64gb-4g-middle-east-version/N70045124V/p/?o=bc7a63c82b154f6c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-silvery-white-12-12gb-ram-256gb-4g-middle-east-version/N70063665V/p/?o=ffb866ab3602c86a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/nokia-6310-black-4g/N53404995A/p/?o=c9930df81b6dd1bd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/hot-30i-dual-sim-marigold-8gb-ram-128gb-4g-lte/N70025239V/p/?o=f85c22cc16fa572c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-lurex-black-12-12gb-ram-256gb-4g-middle-east-version/N70063667V/p/?o=bdbb3a10b7c2f69b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-max-256gb-white-titanium-5g-with-facetime-international-version/N53433290A/p/?o=f00ace4bd141cc5f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sim-blue-black-4gb-ram-128gb-4g-international-version/N70065707V/p/?o=f942aecfffd033ba, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-fold-5-dual-sim-phantom-black-12gb-ram-512gb-5g-international-version/N53424255A/p/?o=a3fa944a1fb2200c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a34-dual-sim-awesome-lime-8gb-ram-256gb-5g-international-version/N53395464A/p/?o=c1b7644d7534adea, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/y28-8gb-ram-128gb-rom-agele-green/N70099859V/p/?o=c3913d09909d266d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-a3-dual-sim-midnight-black-3gb-ram-64gb-4g-global-version/N70052313V/p/?o=eee54baeca7bd8ab, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a38-dual-sim-glowing-gold-6gb-ram-128gb-4g/N70062937V/p/?o=d6b07ac7a42c5fdf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-pro-256gb-white-titanium-5g-with-facetime-middle-east-version/N70105565V/p/?o=a4a03a00ff75288f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/reno-12f-5g-dual-sim-amber-orange-12gb-ram-512gb-international-version/N70096101V/p/?o=c9210460fe2e09aa, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13-dual-sim-sandy-gold-8gb-ram-128gb-4g-middle-east-version/N70108149V/p/?o=e9522de67e3d234a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sim-blue-black-8gb-ram-256gb-4g-international-version/N70065710V/p/?o=c911bbadec60107e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/gt6-dual-sim-fluid-silver-16-12gb-ram-512gb-5g-middle-east-version/N70085258V/p/?o=fc03334189c04b6c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/reno-10-pro-5g-dual-sim-silvery-grey-12gb-ram-256gb-middle-east-version/N53418441A/p/?o=ebaeeacd7f3300bc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a78-dual-sim-mist-black-8gb-ram-256gb-4g-middle-east-version/N53423306A/p/?o=e05ca04d5bc8d3bd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-14-128gb-product-red-5g-with-facetime-middle-east-version/N53347069A/p/?o=f86abd7015e126de, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s23-dual-sim-starry-black-8-8gb-ram-128gb-4g-middle-east-version/N53436924A/p/?o=df7c7b660455597b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-s23-ultra-5g-dual-sim-green-12gb-ram-1tb-middle-east-version/N53378012A/p/?o=dd5a4f1a6fec75ce, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iku-s5-dual-sim-mobile-phone-blue/ZC6E5AE82693EA5859FD1Z/p/?o=zc6e5ae82693ea5859fd1z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-max-256gb-black-titanium-5g-with-facetime-international-version/N53432608A/p/?o=bb7932ee46e16d1c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c51-dual-sim-carbon-black-6gb-ram-256gb-4g-middle-east-version/N70039734V/p/?o=d35f8976522c442a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-a2-dual-sim-black-3gb-ram-64gb-4g-global-version/N53421452A/p/?o=d6fa7611772880da, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/r240-dual-sim-gold-256mb-ram-2g/N34622845A/p/?o=b43da4f421b4eb4e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-azure-blue-4gb-ram-256gb-4g-middle-east-version/N70027156V/p/?o=a8cebf58df1d389f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/hot-30i-dual-sim-glacier-blue-8gb-ram-128gb-4g-lte/N53419089A/p/?o=c12f4975f40b96eb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a34-dual-sim-awesome-graphite-8gb-ram-128gb-5g-international-version/N53395462A/p/?o=b99869dba5c8bdad, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a79-dual-sim-mystery-black-8gb-ram-256gb-5g-lte-middle-east-version/N70045655V/p/?o=c2e64489c3514f2c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7b-dual-sim-6gb-ram-256gb-4g-flowing-silver-with-honor-x6-earbuds-white/N70070456V/p/?o=cd9c76eff4ef546b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c61-dual-sim-dark-green-6-gb-ram-128gb-4g-middle-east-version/N70096179V/p/?o=dfa80d951579bf0e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-128gb-pink-with-20w-adapter-middle-east-version/N70109197V/p/?o=e3a4c943dad199dc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-lurex-black-12-12gb-ram-256gb-4g-middle-east-version/N70063667V/p/?o=bdbb3a10b7c2f69b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8a-dual-sim-midnight-black-8gb-ram-128gb-4g-lte-middle-east-version/N53386101A/p/?o=e0bb9d13ffd6e6ac, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-plus-128gb-black-5g-with-facetime-international-version/N53432593A/p/?o=a99316c4c26fa8cf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-14-plus-128gb-purple-5g-with-facetime-middle-east-version/N53346866A/p/?o=d6957edaf1be2fda, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a05-dual-sim-black-4gb-ram-128gb-4g-lte-middle-east-version/N70027739V/p/?o=f2cde5c39d2ace7f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-128gb-green-5g-with-facetime-international-version/N53433293A/p/?o=f2b676deae4f58cb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s1-mini-dual-sim-grey-1-8-inch-32-mb-ram-32-rom-2g-gsm/N51539613A/p/?o=b8c933de99be0a5d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-glamorous-green-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068555V/p/?o=e0e4c2a30018f1eb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c63-dual-sim-jade-green-6gb-ram-128gb-4g-middle-east-version/N70086807V/p/?o=bdcd3999ab3c4aff, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a25-dual-sim-blue-black-8gb-ram-256gb-5g-middle-east-version/N70029965V/p/?o=c40c1cecd934613c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-titanium-silver-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068556V/p/?o=e96c123a75371b5d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-note-13-dual-sim-ocean-sunset-6gb-ram-128gb-global-version/N70096098V/p/?o=c2a811244e5ca5ad, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13c-dual-sim-midnight-black-6gb-ram-128gb-4g-global-version/N70026397V/p/?o=c7a8395738cbfcea, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/poco-f6-dual-sim-green-12gb-ram-512gb-5g-global-version/N70087936V/p/?o=bce99bbc39d7574d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-sunrise-orange-12gb-ram-256gb-middle-east-version/N70019228V/p/?o=a0eb493dda0d56cd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a17-dual-sim-lake-blue-4gb-ram-64gb-4g-lte-middle-east-version/N53357077A/p/?o=deedfe87d834ca5d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-note-13-dual-sim-midnight-black-8gb-ram-512gb-4g-global-version/N70105521V/p/?o=e92e29970e933eec, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sim-blue-black-6gb-ram-128gb-4g-lte-egypt-version/N70089614V/p/?o=b033498e713cec3f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a22-dual-sim-32gb-internal-memory-2gb-ram-4g-slate-gray/Z1BA3619A20EEF366C6D5Z/p/?o=z1ba3619a20eef366c6d5z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s24-dual-sim-dawn-white-8-8gb-ram-128gb-4g/N70100926V/p/?o=afee18ce68fe751f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/p55-dual-sim-gold-8-gb-ram-128gb-4g/N70101372V/p/?o=d50a314e69ba23ea, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a3x-dual-sim-ocean-blue-4gb-ram-64gb-4g-middle-east-version/N70115970V/p/?o=e750e09ddc8a284b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-a2-dual-sim-black-3gb-ram-64gb-4g-global-version/N53425411A/p/?o=cbbfc1ac9054647f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-12-pro-with-facetime-128gb-graphite-5g-international-specs/N41247234A/p/?o=e487b851dbb1df1a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-midnight-black-12gb-ram-256gb-middle-east-version/N70019226V/p/?o=fba92887b0ca07da, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a7-plus-dual-sim-mobile-16-gb-internal-memory-2gb-ram-3g-network-iron-gray/Z6A38883347C3D29FB9CAZ/p/?o=z6a38883347c3d29fb9caz-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-12c-dual-sim-ocean-blue-6gb-ram-128gb-4g/N70014672V/p/?o=b5f1b664874ac13c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a38-glowing-gold-4gb-ram-128gb-4g-middle-east-version/N53434220A/p/?o=f81680168e456cee, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-pro-max-256gb-natural-titanium-with-20w-adapter-middle-east-version/N70109402V/p/?o=cfdebe0eb3621bcd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x6a-dual-sim-sky-silver-4gb-ram-128gb-4g/N70022031V/p/?o=c36cb27f72645e2d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iku-f102-dual-sim-mobile-phone-blue/Z50C02CA51574B6F3662DZ/p/?o=z50c02ca51574b6f3662dz-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a77-dual-sim-starry-black-negro-4gb-ram-128gb-4g-middle-east-version/N53337189A/p/?o=fdd05bdcade27d0d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/gt-neo-3-dual-sim-nitro-blue-8gb-ram-256gb-5g-80w-international-version/N53368046A/p/?o=e91e872c725e723c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-midnight-black-12gb-ram-256gb-middle-east-version/N70019226V/p/?o=fba92887b0ca07da, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/mobile-fe2-black-32mb-2g-network/Z5BDFF8378DDA7DC0C959Z/p/?o=z5bdff8378dda7dc0c959z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a23-dual-sim-2gb-ram-32gb-internal-memory-6-1-inches-slate-grey/ZAF5DEF84BB12333D5769Z/p/?o=zaf5def84bb12333d5769z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a34-dual-sim-awesome-silver-8gb-ram-128gb-5g-middle-east-version/N53393270A/p/?o=a050e8130fd5d2fa, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-max-1tb-natural-titanium-5g-with-facetime-middle-east-version/N53433277A/p/?o=c010fa2fa4f8f96d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13-dual-sim-midnight-black-8gb-ram-256gb-4g-middle-east-version/N70105384V/p/?o=b537409c3143390e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-flip-6-dual-sim-silver-shadow-12gb-ram-256gb-5g-with-galaxy-buds-3/N70106355V/p/?o=ce25180b80c93e2f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7a-dual-sim-midnight-black-4gb-ram-128gb-4g-lte-middle-east-version/N53380190A/p/?o=f5290c69dc397bbb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-14-plus-128gb-blue-5g-with-facetime-international-version/N53347121A/p/?o=cba9912677218ade, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s3-dual-sim-1-8-inches-display-1000mah-battery-32mb-32mb-black/Z67AE34D243EEF8D4D34FZ/p/?o=z67ae34d243eef8d4d34fz-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-sunrise-orange-12gb-ram-256gb-middle-east-version/N70019228V/p/?o=a0eb493dda0d56cd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s24-dual-sim-dawn-white-8-8gb-ram-128gb-4g/N70100926V/p/?o=afee18ce68fe751f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-12-dual-sim-midnight-black-8gb-ram-256gb-4g-global-version/N53414853A/p/?o=abfb37fe2f222f0c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/hot-30i-dual-sim-diamond-white-4gb-ram-128gb-4g-lte/N53420361A/p/?o=d9deab7c7f350b8d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sm-8gb-ram-256gb-4g-blue-black-with-free-gift-samsung-25w-usb-c-super-fast-charging-travel-adapter-black/N70072799V/p/?o=df71142c43c5e45d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-12-dual-sim-polar-silver-8gb-ram-128gb-4g-global-version/N53414855A/p/?o=a5e79125b0fd84cc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x6a-dual-sim-sky-silver-4gb-ram-128gb-4g/N70022031V/p/?o=c36cb27f72645e2d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-12-pro-with-facetime-256gb-silver-5g-international-version/N41233424A/p/?o=f1e9d1accde86caf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/12-5g-dual-sim-navigator-beige-12gb-ram-512gb-international-version/N70059181V/p/?o=ab670ddb2263381d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-glamorous-green-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068555V/p/?o=e0e4c2a30018f1eb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-lurex-black-12-12gb-ram-256gb-4g-middle-east-version/N70063667V/p/?o=bdbb3a10b7c2f69b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a60s-dual-sim-moonlit-violet-4gb-ram-128gb-4g-middle-east-version/N53436087A/p/?o=f952e7cfc862f01d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s24-dual-sim-dawn-white-8-8gb-ram-128gb-4g/N70100926V/p/?o=afee18ce68fe751f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7a-dual-sim-midnight-black-4gb-ram-128gb-4g-lte-middle-east-version/N53380190A/p/?o=f5290c69dc397bbb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-starlish-black-4gb-ram-256gb-4g-middle-east-version/N70027157V/p/?o=c62cd10bae14348d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-max-512gb-natural-titanium-5g-with-facetime-middle-east-version/N53432934A/p/?o=a5b938cad5d80c0e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13c-dual-sim-glacier-white-6gb-ram-128gb-4g-indian-version/N70049143V/p/?o=d93ce019b72493aa, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-starlish-black-4gb-ram-256gb-4g-middle-east-version/N70027157V/p/?o=c62cd10bae14348d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13c-dual-sim-navy-blue-6gb-ram-128gb-4g-global-version/N70033791V/p/?o=dd72c7a4ac8dd7ee, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-note-12s-dual-sim-onyx-black-8gb-ram-256gb-4g-global-version/N53404737A/p/?o=f39014371994a9ea, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-note-13-pro-5g-12-gb-512-gb-fushion-purple-indian-version/N70036048V/p/?o=ed30852a78a93f3c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7a-dual-sim-midnight-black-4gb-ram-128gb-4g-lte-middle-east-version/N53380190A/p/?o=f5290c69dc397bbb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-pro-max-256gb-natural-titanium-5g-with-facetime-middle-east-version/N70105590V/p/?o=cccda3ef763c5abf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-128gb-black-5g-with-facetime-middle-east-version/N53432546A/p/?o=dcc442f5567958cb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a25-dual-sim-light-blue-6gb-ram-128gb-5g-middle-east-version/N70029339V/p/?o=c17d623b460ca75c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/note-60-dual-sim-marble-black-4gb-ram-128gb-4g-middle-east-version/N70105257V/p/?o=c0946ca9a4d4caad, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a78-dual-sim-mist-black-8gb-ram-256gb-4g/N70010941V/p/?o=ca3bb1b3cb365a1c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-fold-6-dual-sim-navy-12gb-ram-256gb-5g-international-version/N70092358V/p/?o=cf49682f71d4d0ae, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-lurex-black-12-12gb-ram-256gb-4g-middle-east-version/N70063667V/p/?o=bdbb3a10b7c2f69b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13-dual-sim-sandy-gold-8gb-ram-128gb-4g-global-version/N70089475V/p/?o=cc91886a4ca091da, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-fold-6-dual-sim-navy-12gb-ram-512gb-5g-international-version/N70092363V/p/?o=bfc93290d1d8575f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-silvery-white-12-12gb-ram-256gb-4g-middle-east-version/N70063665V/p/?o=ffb866ab3602c86a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-emerald-green-12gb-ram-256gb-middle-east-version/N70019227V/p/?o=c6a0a701df2f830a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sim-yellow-4gb-ram-128gb-4g-egypt-version/N70089611V/p/?o=d6522e76ce0ac15a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/y17s-4g-dual-sim-glitter-purple-6-6gb-ram-128gb-middle-east-version/N70003053V/p/?o=b5fb01e256049c7e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-max-physical-dual-sim-256gb-blue-titanium-5g-without-facetime/N70048568V/p/?o=a8d4c040872ce31b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9-dual-sim-mobile-128gb-internal-memory-8-5gb-ram-4g-lte-midnight-gray/ZD6808D3A7CDB660B1832Z/p/?o=zd6808d3a7cdb660b1832z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-silvery-white-12-12gb-ram-256gb-4g-middle-east-version/N70063665V/p/?o=ffb866ab3602c86a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8a-dual-sim-midnight-black-8gb-ram-128gb-4g-lte-middle-east-version/N53386101A/p/?o=e0bb9d13ffd6e6ac, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/vivo-y02t-dual-sim-64gb-memory-4gb-ram-4g-lte-cosmic-grey-middle-east-version/N70021169V/p/?o=c0c5f62beb95780f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iku-s3-dual-sim-1-8-inches-display-600-mah-battery-gray/Z061AD69D735CDEA59DA2Z/p/?o=z061ad69d735cdea59da2z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a58-dual-sim-dazzling-green-8gb-ram-128gb-4g-middle-east-version/N53426579A/p/?o=d6453903a8cb3d5a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/girasole-g30-2-4-inch-dual-sim-mobile-phone-gold-earphone-free-12-months-warranty/ZE6F657736F5AD790DB1EZ/p/?o=ze6f657736f5ad790db1ez-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-pro-max-1tb-desert-titanium-5g-with-facetime-international-version/N70106159V/p/?o=efd2373407a14e4f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a23-dual-sim-2gb-ram-32gb-internal-memory-6-1-inches-slate-grey/ZEA0946915DE260BEB9D4Z/p/?o=zea0946915de260beb9d4z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a05s-android-smartphone-dual-sim-mobile-phone-lte-6gb-ram-128gb-storage-uae-version/N70027677V/p/?o=ea853a024ac9569f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/v30-5g-dual-sim-lush-green-12gb-ram-256gb-middle-east-version/N70052196V/p/?o=fb1b851b6d3f34fe, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/poco-f6-dual-sim-black-12gb-ram-512gb-5g-international-version/N70088006V/p/?o=ac022338b81de38e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7a-dual-sim-midnight-black-4gb-ram-128gb-4g-lte-middle-east-version/N53380190A/p/?o=f5290c69dc397bbb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iku-f102-dual-sim-mobile-phone-grey/Z1710E8A73D962F3D8A39Z/p/?o=z1710e8a73d962f3d8a39z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7b-dual-sim-6gb-ram-256gb-4g-flowing-silver-with-honor-x6-earbuds-white/N70070456V/p/?o=cd9c76eff4ef546b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a55-dual-sim-awesome-lilac-8gb-ram-128gb-5g-middle-east-version/N70049912V/p/?o=a0f0128cd0f87ebb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-s24-ultra-dual-sim-titanium-violet-12gb-ram-512gb-5g-middle-east-version/N70035271V/p/?o=cf9cb28b173f3bdc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-azure-blue-4gb-ram-256gb-4g-middle-east-version/N70027156V/p/?o=a8cebf58df1d389f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-azure-blue-4gb-ram-256gb-4g-middle-east-version/N70027156V/p/?o=a8cebf58df1d389f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-128gb-teal-5g-with-facetime-international-version/N70106133V/p/?o=c603f910a469d18d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/r240-dual-sim-grey-256mb-ram-512mb-2g/N34622846A/p/?o=e6026de5a2848baf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8a-dual-sim-midnight-black-8gb-ram-128gb-4g-lte-middle-east-version/N53386101A/p/?o=e0bb9d13ffd6e6ac, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/y18-4g-dual-sim-mocha-brown-6gb-ram-128gb-middle-east-version/N70072467V/p/?o=b66235cb0124fcaf, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-azure-blue-4gb-ram-256gb-4g-middle-east-version/N70027156V/p/?o=a8cebf58df1d389f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/reno-6-black-dual-sim-8gb-ram-128gb-4g-lte/N50667558A/p/?o=fd3c0e452df5cd5e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a18-dual-sim-4gb-ram-128gb-rom-glowing-black-4g-international-version/N70045421V/p/?o=e9ee0e59b225d5cb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-note-12s-dual-sim-ice-blue-8gb-ram-256gb-4g-global-version/N53404740A/p/?o=ec4d837f6d9503ec, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmagic-9s-pro-dual-sim-frost-12gb-ram-256gb-5g-international-version/N70096077V/p/?o=a9aab1b1bfa6b36a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c67-dual-sim-sunny-oasis-8gb-ram-256gb-4g-uae-version/N70034344V/p/?o=d409beda21996abe, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-azure-blue-4gb-ram-256gb-4g-middle-east-version/N70027156V/p/?o=a8cebf58df1d389f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13c-dual-sim-stardust-black-6gb-ram-128gb-4g-global-version/N70028350V/p/?o=a298bfe9f96814bd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-128gb-natural-titanium-5g-with-facetime-middle-east-version/N53432636A/p/?o=d3104861977d0bfb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-s24-ultra-dual-sim-titanium-gray-12gb-ram-256gb-5g-international-version/N70036948V/p/?o=e62288f8a083a6bb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-pro-max-physical-dual-sim-256gb-black-titanium-5g-without-facetime/N70106333V/p/?o=ae00f0e85ce023ca, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13-dual-sim-ocean-blue-8gb-ram-128gb-4g-global-version/N70088715V/p/?o=de22803e62b394fb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7b-dual-sim-6gb-ram-256gb-4g-flowing-silver-with-honor-x6-earbuds-white/N70070456V/p/?o=cd9c76eff4ef546b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/12-5g-dual-sim-woodland-green-8gb-ram-512gb-international-version/N70059171V/p/?o=c54d250b59d3634d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8-dual-sim-4-3gb-ram-64gb-internal-memory-starlight-purple/Z819C0077085C67D948C2Z/p/?o=z819c0077085c67d948c2z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7b-dual-sim-flowing-silver-6gb-ram-256gb-4g/N70045230V/p/?o=d08b5dc2ed54057c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/p55-dual-sim-brilliant-gold-8-16gb-ram-256gb-4g-middle-east-version/N70065148V/p/?o=e04d33fc9062dd4a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-12c-dual-sim-ocean-blue-4gb-ram-128gb-4g-global-version/N53385337A/p/?o=e1b9f9271793c60c, skipping.
# ...
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-128gb-black-5g-with-facetime-international-version/N70106131V/p/?o=cbabced25eb6355b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7b-dual-sim-6gb-ram-256gb-4g-flowing-silver-with-honor-x6-earbuds-white/N70070456V/p/?o=cd9c76eff4ef546b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-max-512gb-natural-titanium-5g-with-facetime-international-version/N53432567A/p/?o=be29eef8ee1fe07d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-emerald-green-12gb-ram-256gb-middle-east-version/N70019227V/p/?o=c6a0a701df2f830a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a34-dual-sim-awesome-silver-8gb-ram-128gb-5g-egypt-version/N53415816A/p/?o=a586242d2350114c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-azure-blue-4gb-ram-256gb-4g-middle-east-version/N70027156V/p/?o=a8cebf58df1d389f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/nubia-red-magic-8s-pro-dual-sim-platinum-16gb-ram-512gb-5g-international-version/N53419533A/p/?o=e7a117d65d948edc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sim-blue-black-6gb-ram-128gb-4g-lte-middle-east-version-with-free-gift-generic-t800-ultra-series-8-2023-smart-watch/N70072002V/p/?o=c070470e9fc2b72c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-midnight-black-12gb-ram-256gb-middle-east-version/N70019226V/p/?o=fba92887b0ca07da, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/11-pro-sunrise-beige-dual-sim-12gb-ram-512gb-5g-international-version/N70051698V/p/?o=ed78c43513f217bd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-note-9-pro-dual-sim-interstellar-grey-6gb-ram-64gb-4g-lte-international-version/N38249430A/p/?o=db26c17177194b5c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-256gb-black-titanium-5g-with-facetime-international-version/N53432522A/p/?o=fdabf4e429c8bcff, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-fold-6-dual-sim-silver-shadow-12gb-ram-256gb-5g-with-galaxy-buds-3/N70106261V/p/?o=a42841b8dac6565a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/105-2023-dual-sim-ocean-blue-48mb-ram-128mb-4g-middle-east-version/N53418633A/p/?o=e52f66942abc878b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sim-light-blue-4gb-ram-128gb-4g-international-version/N70062088V/p/?o=c1fcb31c07be416e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-field-green-3-5-gb-ram-64gb-4g-middle-east-version/N70027158V/p/?o=a4590eede07a731e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sim-yellow-8gb-ram-256gb-4g-egypt-version/N70089605V/p/?o=e16acf2b5b38adde, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/105-dual-sim-black-4mb-ram-4mb-2g/N30216127A/p/?o=ca74040916cbb57c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/realme-p1-pro-5g-12gb-ram-256gb-phoenix-red-middle-east-version/N70118871V/p/?o=f710705d4605b01c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/oppo-a60-256gb-8gb-ram-4g-lte-dual-sim-purple-international-version-with-a-gift-t800-ultra-smart-watch-1-9-inch-orange/N70101172V/p/?o=dafcfbda01bf7a5c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13-dual-sim-midnight-black-6gb-ram-128gb-4g-middle-east-version/N70105378V/p/?o=d0974b7bb593e97a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-glamorous-green-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068555V/p/?o=e0e4c2a30018f1eb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-titanium-silver-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068556V/p/?o=e96c123a75371b5d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7b-dual-sim-6gb-ram-256gb-4g-midnight-black-with-honor-x6-earbuds-white/N70070455V/p/?o=acec4395fb86acad, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/y18-4g-dual-sim-wave-aqua-6gb-ram-128gb-middle-east-version/N70072468V/p/?o=ae0f3c1a3c54122a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/12-pro-5g-dual-sim-navigator-beige-8gb-ram-256gb-international-version/N70043147V/p/?o=dbc46796b59d7c6b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9-dual-sim-mobile-128gb-internal-memory-8-5gb-ram-4g-lte-starlight-blue/Z144CD17B6ACA0FBAA5B3Z/p/?o=z144cd17b6aca0fbaa5b3z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c67-dual-sim-sunny-oasis-verde-8gb-ram-256gb-4g-international-version/N70057430V/p/?o=de72aa5e30a9756b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/gt6-5g-dual-sim-razor-green-12gb-ram-256gb-5g-international-version/N70087083V/p/?o=d7f48bb0fed845ad, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/smart-7-dual-sim-peacock-blue-3gb-ram-64gb-4g-lte/N53410862A/p/?o=f6a635281329229d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-pro-max-physical-dual-sim-512gb-natural-titanium-5g-without-facetime/N70106065V/p/?o=fb9194703a88fa2b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-silvery-white-12-12gb-ram-256gb-4g-middle-east-version/N70063665V/p/?o=ffb866ab3602c86a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-azure-blue-4gb-ram-256gb-4g-middle-east-version/N70027156V/p/?o=a8cebf58df1d389f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a35-dual-sim-awesome-navy-8gb-ram-128gb-5g-middle-east-version-with-a-free-gift-generic-air-puds-pro-2nd-gen-in-earbuds-white/N70106576V/p/?o=e792ec6bf5d876ec, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a35-dual-sim-awesome-navy-8gb-ram-128gb-5g-middle-east-version-with-a-free-gift-t800-ultra-smart-watch-1-9-inch-orange/N70100854V/p/?o=a7573c194f85701b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-15-pro-max-512gb-blue-titanium-5g-with-facetime-international-version/N53432488A/p/?o=bcc41cbb7f90e6cc, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x6a-dual-sim-sky-silver-4gb-ram-128gb-4g/N70022031V/p/?o=c36cb27f72645e2d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c67-dual-sim-black-rock-8gb-ram-256gb-4g-uae-version/N70034345V/p/?o=bd4486d96793202c, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8b-dual-sim-glamorous-green-8gb-ram-512gb-4g-lte-with-honor-earbuds-x6/N70068555V/p/?o=e0e4c2a30018f1eb, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/reno-6-5g-dual-sim-stellar-black-8gb-ram-128gb-middle-east-version/N50647927A/p/?o=e3bc17371ba30e4d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-lurex-black-12-12gb-ram-256gb-4g-middle-east-version/N70063667V/p/?o=bdbb3a10b7c2f69b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-z-fold-4-5g-dual-sim-beige-12gb-ram-512gb-international-version/N53344203A/p/?o=d1ee1b36862ddf2d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7b-dual-sim-6gb-ram-256gb-4g-flowing-silver-with-honor-x6-earbuds-white/N70070456V/p/?o=cd9c76eff4ef546b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/m21-dual-sim-1-77-inches-2500mah-battery-2g-black/Z1B3651C4035F0D3045C1Z/p/?o=z1b3651c4035f0d3045c1z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-a3-dual-sim-star-blue-3gb-ram-64gb-4g-global-version/N70060086V/p/?o=f2b6d346d45f26ee, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-pro-256gb-desert-titanium-5g-with-facetime-international-version/N70106148V/p/?o=a8474f87db1ae05e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s24-dual-sim-dawn-white-8-8gb-ram-128gb-4g/N70100926V/p/?o=afee18ce68fe751f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-note-12-dual-sim-sunrise-gold-8gb-ram-128gb-4g-global-version/N53421307A/p/?o=f742ba152bbc865a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s1-dual-sim-grey-1-77-inch-32-mb-ram-32-ram-2g-gsm/N51539609A/p/?o=b8b70e6d0d64662e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a70-dual-sim-starlish-black-4gb-ram-256gb-4g-middle-east-version/N70027157V/p/?o=c62cd10bae14348d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s24-dual-sim-dawn-white-8-8gb-ram-128gb-4g/N70100926V/p/?o=afee18ce68fe751f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x7b-dual-sim-6gb-ram-256gb-4g-flowing-silver-with-honor-x6-earbuds-white/N70070456V/p/?o=cd9c76eff4ef546b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/200-5g-dual-sim-emerald-green-12gb-ram-512gb-middle-east-version/N70091759V/p/?o=de2d311a05b6daea, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iku-f102-dual-sim-mobile-phone-green/Z371D238BB75AC42A5832Z/p/?o=z371d238bb75ac42a5832z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/iphone-16-128gb-black-5g-with-facetime-middle-east-version/N70105548V/p/?o=e9c00dc31271a3fd, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/m21-dual-sim-1-77-inches-2500mah-battery-2g-red/ZAD6496A3A46D4365BC35Z/p/?o=zad6496a3a46d4365bc35z-1, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-emerald-green-12gb-ram-256gb-5g-with-honor-choice-earbuds-x5/N70045711V/p/?o=c2383b9f772907ce, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s24-dual-sim-dawn-white-8-8gb-ram-128gb-4g/N70100926V/p/?o=afee18ce68fe751f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-midnight-black-12gb-ram-256gb-middle-east-version/N70019226V/p/?o=fba92887b0ca07da, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/s24-dual-sim-dawn-white-8-8gb-ram-128gb-4g/N70100926V/p/?o=afee18ce68fe751f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a15-dual-sim-light-blue-8gb-ram-256gb-4g-middle-east-version-with-free-gift-samsung-25w-adapter-usb-c-super-fast-charging-travel-adapter-eu-plug-black-color-of-the-gift-charger-may-vary/N70072078V/p/?o=cf9f9cb8b8fb9c3a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-emerald-green-12gb-ram-256gb-middle-east-version/N70019227V/p/?o=c6a0a701df2f830a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a24-black-6gb-128gb-4g-lte-egypt-version/N53408146A/p/?o=a87113ec6e4f5f2d, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/redmi-13c-dual-sim-clover-green-starshine-green-6gb-ram-128gb-4g-india-version/N70049145V/p/?o=d97853a95215b44b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/8i-dual-sim-space-purple-morado-6gb-ram-128gb-4g-lte-international-version/N51550890A/p/?o=f1b5e956a7f56eff, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x8a-dual-sim-8gb-ram-128gb-4g-lte-titanium-silver-with-honor-x6-earbuds-white/N70070454V/p/?o=af864d8bedc4b93f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/12-dual-sim-silky-black-16gb-ram-512gb-5g-international-version/N70042230V/p/?o=da024cdd20a9bb1e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-lurex-black-12-12gb-ram-256gb-4g-middle-east-version/N70063667V/p/?o=bdbb3a10b7c2f69b, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/rs4-dual-sim-silvery-white-12-12gb-ram-256gb-4g-middle-east-version/N70063665V/p/?o=ffb866ab3602c86a, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/galaxy-a05-dual-sim-light-green-4gb-ram-128gb-4g-lte-middle-east-version/N70029328V/p/?o=b06c5ef5b98bc8ae, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/nokia-106-2023-dual-sim-black/N70010648V/p/?o=f5706b1e8ad6868f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/x9b-dual-sim-5g-midnight-black-12gb-ram-256gb-middle-east-version/N70019226V/p/?o=fba92887b0ca07da, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c65-dual-sim-purple-8gb-ram-128gb-4g-middle-east-version/N70115281V/p/?o=b22e39d2200e335e, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/a60s-dual-sim-shadow-black-4gb-ram-128gb-4g-middle-east-version/N53420650A/p/?o=c749fdfbab56a22f, skipping.
# WARNING:root:Incomplete data for product: https://www.noon.com/egypt-en/c31-dual-sim-mint-4gb-ram-64gb-4g/N53436434A/p/?o=e94fc8c7e0ed9cda, skipping.
#   Secondary Camera Resolution Charging Type SIM Count Secondary Camera  \
# 0                        8 MP        Type-C  Dual SIM      8 - 11.9 MP
# 1                        8 MP        Type-C  Dual SIM      8 - 11.9 MP
# 2                       16 MP        Type-C  Dual SIM     16 - 31.9 MP
# 3                       13 MP        Type-C  Dual SIM     12 - 15.9 MP
# 4                        2 MP        Type-C  Dual SIM      Upto 4.9 MP
#
#   RAM Size Battery Size Internal Memory              Version Screen Size  \
# 0     4 GB     5000 mAh          256 GB  Middle East Version      6.6 in
# 1     4 GB     6000 mAh          128 GB  Middle East Version     6.75 in
# 2    12 GB     5800 mAh          256 GB  Middle East Version     6.78 in
# 3     8 GB     5000 mAh          256 GB  Middle East Version      6.5 in
# 4     4 GB     5000 mAh          128 GB  Middle East Version      6.7 in
#
#    SIM Type  ... Refresh Rates Display Resolution Type Glass Technology  \
# 0  Nano SIM  ...           NaN                     NaN              NaN
# 1  Nano SIM  ...           NaN                     NaN              NaN
# 2  Nano SIM  ...           NaN                     NaN              NaN
# 3  Nano SIM  ...          90Hz                     NaN              NaN
# 4  Nano SIM  ...          90Hz                     NaN              NaN
#
#   Video Recording Resolution Type Finish Camera Type Battery Type  \
# 0                             NaN    NaN         NaN          NaN
# 1                             NaN    NaN         NaN          NaN
# 2                             NaN    NaN         NaN          NaN
# 3                             NaN    NaN         NaN          NaN
# 4                             NaN    NaN         NaN          NaN
#
#   Pixels Per Inch Network Wireless
# 0             NaN     NaN      NaN
# 1             NaN     NaN      NaN
# 2             NaN     NaN      NaN
# 3             NaN     NaN      NaN
# 4             NaN     NaN      NaN
#
# [5 rows x 57 columns]

# %%
from datetime import datetime
import pandas as pd # Import the pandas library

# Get the current date and time
now = datetime.now()

# dd/mm/YY H:M:S
today = now.strftime("%d/%m/%Y:%H:%M")
today=pd.to_datetime(today, format="%d/%m/%Y:%H:%M") # Explicitly specify the format

# %%
df=pd.DataFrame(product_data)
df.to_csv(f'noon_raw{today}.csv', index=False)
df.head()
# Out:
#   Secondary Camera Resolution Charging Type SIM Count Secondary Camera  \
# 0                        8 MP        Type-C  Dual SIM      8 - 11.9 MP
# 1                        8 MP        Type-C  Dual SIM      8 - 11.9 MP
# 2                       16 MP        Type-C  Dual SIM     16 - 31.9 MP
# 3                       13 MP        Type-C  Dual SIM     12 - 15.9 MP
# 4                        2 MP        Type-C  Dual SIM      Upto 4.9 MP
#
#   RAM Size Battery Size Internal Memory              Version Screen Size  \
# 0     4 GB     5000 mAh          256 GB  Middle East Version      6.6 in
# 1     4 GB     6000 mAh          128 GB  Middle East Version     6.75 in
# 2    12 GB     5800 mAh          256 GB  Middle East Version     6.78 in
# 3     8 GB     5000 mAh          256 GB  Middle East Version      6.5 in
# 4     4 GB     5000 mAh          128 GB  Middle East Version      6.7 in
#
#    SIM Type  ... Refresh Rates Display Resolution Type Glass Technology  \
# 0  Nano SIM  ...           NaN                     NaN              NaN
# 1  Nano SIM  ...           NaN                     NaN              NaN
# 2  Nano SIM  ...           NaN                     NaN              NaN
# 3  Nano SIM  ...          90Hz                     NaN              NaN
# 4  Nano SIM  ...          90Hz                     NaN              NaN
#
#   Video Recording Resolution Type Finish Camera Type Battery Type  \
# 0                             NaN    NaN         NaN          NaN
# 1                             NaN    NaN         NaN          NaN
# 2                             NaN    NaN         NaN          NaN
# 3                             NaN    NaN         NaN          NaN
# 4                             NaN    NaN         NaN          NaN
#
#   Pixels Per Inch Network Wireless
# 0             NaN     NaN      NaN
# 1             NaN     NaN      NaN
# 2             NaN     NaN      NaN
# 3             NaN     NaN      NaN
# 4             NaN     NaN      NaN
#
# [5 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 57 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Secondary Camera Resolution      147 non-null    object
#  1   Charging Type                    176 non-null    object
#  2   SIM Count                        220 non-null    object
#  3   Secondary Camera                 147 non-null    object
#  4   RAM Size                         222 non-null    object
#  5   Battery Size                     222 non-null    object
#  6   Internal Memory                  222 non-null    object
#  7   Version                          221 non-null    object
#  8   Screen Size                      222 non-null    object
#  9   SIM Type                         219 non-null    object
#  10  Colour Name                      220 non-null    object
#  11  Voice Calling Capability         96 non-null     object
#  12  Processor Number                 113 non-null    object
#  13  Network Frequency Band           120 non-null    object
#  14  Processor Name                   91 non-null     object
#  15  Number of Cores                  119 non-null    object
#  16  Network Type                     166 non-null    object
#  17  Condition                        200 non-null    object
#  18  Model Number                     217 non-null    object
#  19  Model Name                       212 non-null    object
#  20  Primary Camera (MP)              135 non-null    object
#  21  Title                            222 non-null    object
#  22  Price                            222 non-null    object
#  23  Brand                            222 non-null    object
#  24  Rating                           222 non-null    object
#  25  Product Image                    222 non-null    object
#  26  Product Link                     222 non-null    object
#  27  Expandable Memory Type           117 non-null    object
#  28  Processor Speed                  65 non-null     object
#  29  Display Resolution               67 non-null     object
#  30  Display Type                     92 non-null     object
#  31  Operating System Version         61 non-null     object
#  32  Operating System                 159 non-null    object
#  33  Primary Camera Feature           102 non-null    object
#  34  Model Year                       124 non-null    object
#  35  Maximum Expandable Memory        56 non-null     object
#  36  Product Weight                   74 non-null     object
#  37  Operating System Number          82 non-null     object
#  38  Fast Charging                    81 non-null     object
#  39  What's In The Box                71 non-null     object
#  40  Flash                            68 non-null     object
#  41  Audio Jack                       35 non-null     object
#  42  Water/Dust Properties            31 non-null     object
#  43  Product Length                   73 non-null     object
#  44  Product Height                   77 non-null     object
#  45  Product Width/Depth              78 non-null     object
#  46  Sensor                           62 non-null     object
#  47  Refresh Rates                    85 non-null     object
#  48  Display Resolution Type          33 non-null     object
#  49  Glass Technology                 21 non-null     object
#  50  Video Recording Resolution Type  22 non-null     object
#  51  Finish                           12 non-null     object
#  52  Camera Type                      10 non-null     object
#  53  Battery Type                     4 non-null      object
#  54  Pixels Per Inch                  8 non-null      object
#  55  Network                          4 non-null      object
#  56  Wireless                         1 non-null      object
# dtypes: object(57)
# memory usage: 99.0+ KB

# %% [markdown]
# # Saving the output of the scraping code to the datalake

# %%
from azure.storage.blob import BlobServiceClient

# Your Azure connection string
connection_string = "DefaultEndpointsProtocol=https;AccountName=noon;AccountKey=d2CI4UUSt0o5owVHuKgR/baEGSWZ2vMWIAD3p38DCsScpHUALrqIheG4EIyLbM809DGlwrTXNU0B+AStzkSOnw==;EndpointSuffix=core.windows.net"

# Initialize BlobServiceClient
blob_service_client = BlobServiceClient.from_connection_string(connection_string)

# Local file path
local_file_path = f"noon_raw{today}.csv"

# Container and blob details
container_name = "proj"
blob_name = f"Raw/noon_raw{today}.csv"  # File in 'Transformed' folder

# Create a BlobClient
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

# Upload the file
with open(local_file_path, "rb") as data:
    blob_client.upload_blob(data)

print(f"File {local_file_path} uploaded to container '{container_name}' under '{blob_name}'")
# Out:
# File /content/noon_raw2024-10-20 03:33:00.csv uploaded to container 'proj' under 'Raw/noon_raw2024-10-20 03:33:00.csv'

# %% [markdown]
# # Transformation

# %% [markdown]
# ####  Reading the data from the datalake

# %%
# to avoid consuming the stream before reading
from io import BytesIO
download_stream = blob_client.download_blob().readall()
data_stream = BytesIO(download_stream)

# Read the data into a Pandas DataFrame
df = pd.read_csv(data_stream)

# Now you have the data in a DataFrame called 'df'
df.head()
# Out:
#   Secondary Camera Resolution Charging Type SIM Count Secondary Camera  \
# 0                        8 MP        Type-C  Dual SIM      8 - 11.9 MP
# 1                        8 MP        Type-C  Dual SIM      8 - 11.9 MP
# 2                       16 MP        Type-C  Dual SIM     16 - 31.9 MP
# 3                       13 MP        Type-C  Dual SIM     12 - 15.9 MP
# 4                        2 MP        Type-C  Dual SIM      Upto 4.9 MP
#
#   RAM Size Battery Size Internal Memory              Version Screen Size  \
# 0     4 GB     5000 mAh          256 GB  Middle East Version      6.6 in
# 1     4 GB     6000 mAh          128 GB  Middle East Version     6.75 in
# 2    12 GB     5800 mAh          256 GB  Middle East Version     6.78 in
# 3     8 GB     5000 mAh          256 GB  Middle East Version      6.5 in
# 4     4 GB     5000 mAh          128 GB  Middle East Version      6.7 in
#
#    SIM Type  ... Refresh Rates Display Resolution Type Glass Technology  \
# 0  Nano SIM  ...           NaN                     NaN              NaN
# 1  Nano SIM  ...           NaN                     NaN              NaN
# 2  Nano SIM  ...           NaN                     NaN              NaN
# 3  Nano SIM  ...          90Hz                     NaN              NaN
# 4  Nano SIM  ...          90Hz                     NaN              NaN
#
#   Video Recording Resolution Type Finish Camera Type Battery Type  \
# 0                             NaN    NaN         NaN          NaN
# 1                             NaN    NaN         NaN          NaN
# 2                             NaN    NaN         NaN          NaN
# 3                             NaN    NaN         NaN          NaN
# 4                             NaN    NaN         NaN          NaN
#
#   Pixels Per Inch Network Wireless
# 0             NaN     NaN      NaN
# 1             NaN     NaN      NaN
# 2             NaN     NaN      NaN
# 3             NaN     NaN      NaN
# 4             NaN     NaN      NaN
#
# [5 rows x 57 columns]

# %%
# selecting the necessary columns

selected_columns=['RAM Size',
 'Battery Size',
 'Internal Memory',
 'Screen Size',
 'Colour Name',
 'Title',
 'Price',
 'Brand',
 'Rating',
 'Product Image',
 'Product Link',
 'Version',
 'Model Name',
 'Primary Camera (MP)',
 'Secondary Camera Resolution',
 'Refresh Rates',
 'Operating System',
 'Operating System Version',
 'Processor Speed',
 'Network Type',
 'Model Year',
 'Display Resolution']

df=df[selected_columns]
df.rename(columns={'Operating System':'os','Operating System Version':'os_version','RAM Size':'ram',
                         'Internal Memory':'storage'}, inplace=True)

#drop nulls in model name
df.dropna(subset=['Model Name'], inplace=True)
df.reset_index(drop=True, inplace=True)

# Convert all values to lowercase
df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
# <ipython-input-220-78084be7c99b>:35: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ram                          212 non-null    object
#  1   Battery Size                 212 non-null    object
#  2   storage                      212 non-null    object
#  3   Screen Size                  212 non-null    object
#  4   Colour Name                  212 non-null    object
#  5   Title                        212 non-null    object
#  6   Price                        212 non-null    object
#  7   Brand                        212 non-null    object
#  8   Rating                       208 non-null    float64
#  9   Product Image                212 non-null    object
#  10  Product Link                 212 non-null    object
#  11  Version                      211 non-null    object
#  12  Model Name                   212 non-null    object
#  13  Primary Camera (MP)          135 non-null    object
#  14  Secondary Camera Resolution  142 non-null    object
#  15  Refresh Rates                85 non-null     object
#  16  os                           159 non-null    object
#  17  os_version                   61 non-null     object
#  18  Processor Speed              62 non-null     object
#  19  Network Type                 166 non-null    object
#  20  Model Year                   124 non-null    float64
#  21  Display Resolution           66 non-null     object
# dtypes: float64(2), object(20)
# memory usage: 36.6+ KB

# %%
import re
spec=[]
def parse_camera_spec(camera_spec):
    # Check if camera_spec is a valid string
    if isinstance(camera_spec, str):
        # Remove non-numeric characters except for plus signs and split by plus
        numbers = re.findall(r'\d+', camera_spec)

        # Convert the list of strings into integers
        return [int(num) for num in numbers]
    else:
        # Handle missing or invalid values
        return []

# Iterate over the column to apply the function to each row
for camera_spec in df['Primary Camera (MP)']:
  output = parse_camera_spec(camera_spec)
  spec.append(sorted(output,reverse=True))

df['Primary Camera (MP)']=spec

def sum_list_elements(lst):
  if isinstance(lst, list):
    return sum(lst)
  else:
    return lst  # Handle cases where it's not a list

df['Primary Camera (MP)'] = df['Primary Camera (MP)'].apply(sum_list_elements)

# %%
sam_df=df[df['Model Name'].str.contains('sm-')]
sam_df['Model Name']
sam_phones=[]
specific_elements=['galaxy','dual','sim']
for i in sam_df['Title'].str.split():
  sam_phones.append(' '.join([x for x in i[0:4] if x not in specific_elements]))

# Create a dictionary to map the indices to sam_phones values
sam_phones_dict = {i: val for i, val in enumerate(sam_phones)}

# Use map to replace the values in the Model Name column
df.loc[df['Model Name'].str.contains('sm-'), 'Model Name'] = df.groupby(df['Model Name'].str.contains('sm-')).ngroup().map(sam_phones_dict)
unused=['oppo','galaxy','gray','titanium','samsung','black','blue','nokia','realme','iphone','4g','5g','oneplus','mobile phone']
for i in unused:
  df['Model Name']=df['Model Name'].str.replace(i,'')

df['Model Name']=df['Model Name'].str.split(',').str[0].str.replace('+',' plus')

# %%
# Function to clean and extract model name
def extract_model_name(model_name):
    # Use regular expression to capture the main model name (alphanumeric + spaces)
    # This pattern extracts only the first two alphanumeric words
    match = re.match(r'^([\w\d\s]+)\b', model_name)

    if match:
        # Return the extracted model name, strip any extra spaces
        return match.group(1).strip()
    else:
        return model_name  # Return original if no match

# Apply the function to the "Model Name" column
df['Model Name'] = df['Model Name'].apply(extract_model_name)

df['os_version']=df['os_version'].str.split().str[1]

# %%
from datetime import datetime
# Assuming 'column_name' is the column you want to clean
df['Price'] = df['Price'].str.extract('(\d+\.?\d*)').astype(float).fillna(0).astype(int) # Changed to float first, then filled NaN with 0, then int

# Extract the digits and convert to float
df['ram'] = df['ram'].str.extract('(\d+\.?\d*)').astype(float).fillna(0).astype(int)

# Extract the digits and convert to float
df['Screen Size'] = df['Screen Size'].str.extract('(\d+\.?\d*)').astype(float).fillna(0)
df['storage'] = df['storage'].str.extract('(\d+\.?\d*)').astype(float).fillna(0).astype(int)
df['Refresh Rates'] = df['Refresh Rates'].str.extract('(\d+\.?\d*)').astype(float).fillna(0).astype(int)
df['Processor Speed'] = df['Processor Speed'].str.extract('(\d+\.?\d*)').astype(float).fillna(0)
df['Secondary Camera Resolution']=df['Secondary Camera Resolution'].str.split().str[0]


# Add the new column with the date value
df['date'] = datetime.now().date()

# Reorder the DataFrame to place the new column first
df = df[['date'] + [col for col in df.columns if col != 'date']]
df['site'] = 'noon'
df['category'] = 'mobile phones'
# Out:
# <ipython-input-225-b42beaa7301a>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['site'] = 'noon'
# <ipython-input-225-b42beaa7301a>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['category'] = 'mobile phones'

# %%
# Replace all zeroes with NaNs
import numpy as np
import re

df.replace(0, np.nan, inplace=True)
# Replace empty strings and spaces with NaNs
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)
# Convert `date_column` to datetime
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y', errors='coerce')

# Convert `price_usd` to numeric
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# Convert `ram_gb`, `storage`, `screen_size_in`, `refresh_rate_hz`, `cpu_speed_ghz` to numeric
df['ram'] = pd.to_numeric(df['ram'], errors='coerce')
df['storage'] = pd.to_numeric(df['storage'], errors='coerce')
df['Screen Size'] = pd.to_numeric(df['Screen Size'], errors='coerce')
df['Refresh Rates'] = pd.to_numeric(df['Refresh Rates'], errors='coerce')
df['Processor Speed'] = pd.to_numeric(df['Processor Speed'], errors='coerce')
df['Secondary Camera Resolution']=df['Secondary Camera Resolution'].astype(float)
# Clean and convert 'Battery Size' to numeric
df['Battery Size'] = df['Battery Size'].str.replace(r"[a-zA-Z\s]+", "", regex=True)  # Remove all letters and spaces
df['Battery Size'] = pd.to_numeric(df['Battery Size'], errors='coerce').fillna(0).astype(int)  # Convert to numeric, handle errors, fill NaN with 0
df['Model Year']=pd.to_numeric(df['Model Year'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         212 non-null    datetime64[ns]
#  1   ram                          212 non-null    int64
#  2   Battery Size                 212 non-null    int64
#  3   storage                      212 non-null    int64
#  4   Screen Size                  212 non-null    float64
#  5   Colour Name                  212 non-null    object
#  6   Title                        212 non-null    object
#  7   Price                        212 non-null    int64
#  8   Brand                        212 non-null    object
#  9   Rating                       208 non-null    float64
#  10  Product Image                212 non-null    object
#  11  Product Link                 212 non-null    object
#  12  Version                      211 non-null    object
#  13  Model Name                   212 non-null    object
#  14  Primary Camera (MP)          135 non-null    float64
#  15  Secondary Camera Resolution  142 non-null    float64
#  16  Refresh Rates                85 non-null     float64
#  17  os                           159 non-null    object
#  18  os_version                   61 non-null     object
#  19  Processor Speed              62 non-null     float64
#  20  Network Type                 166 non-null    object
#  21  Model Year                   124 non-null    float64
#  22  Display Resolution           66 non-null     object
#  23  site                         212 non-null    object
#  24  category                     212 non-null    object
# dtypes: datetime64[ns](1), float64(7), int64(4), object(13)
# memory usage: 41.5+ KB
# <ipython-input-226-8da700f6b307>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace(0, np.nan, inplace=True)
# <ipython-input-226-8da700f6b307>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace(r'^\s*$', np.nan, regex=True, inplace=True)
# <ipython-input-226-8da700f6b307>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y', errors='coerce')
# <ipython-input-226-8da700f6b307>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
# <ipython-input-226-8da700f6b307>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ram'] = pd.to_numeric(df['ram'], errors='coerce')
# <ipython-input-226-8da700f6b307>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['storage'] = pd.to_numeric(df['storage'], errors='coerce')
# <ipython-input-226-8da700f6b307>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Screen Size'] = pd.to_numeric(df['Screen Size'], errors='coerce')
# <ipython-input-226-8da700f6b307>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Refresh Rates'] = pd.to_numeric(df['Refresh Rates'], errors='coerce')
# <ipython-input-226-8da700f6b307>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Processor Speed'] = pd.to_numeric(df['Processor Speed'], errors='coerce')
# <ipython-input-226-8da700f6b307>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Secondary Camera Resolution']=df['Secondary Camera Resolution'].astype(float)
# <ipython-input-226-8da700f6b307>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Battery Size'] = df['Battery Size'].str.replace(r"[a-zA-Z\s]+", "", regex=True)  # Remove all letters and spaces
# <ipython-input-226-8da700f6b307>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Battery Size'] = pd.to_numeric(df['Battery Size'], errors='coerce').fillna(0).astype(int)  # Convert to numeric, handle errors, fill NaN with 0
# <ipython-input-226-8da700f6b307>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Model Year']=pd.to_numeric(df['Model Year'])

# %%
df.to_csv(f'noon_transformed{today}.csv', index=False)
df.head()
# Out:
#         date  ram  Battery Size  storage  Screen Size     Colour Name  \
# 0 2024-10-20    4          5000      256         6.60  starlish black
# 1 2024-10-20    4          6000      128         6.75  midnight black
# 2 2024-10-20   12          5800      256         6.78  midnight black
# 3 2024-10-20    8          5000      256         6.50      blue/black
# 4 2024-10-20    4          5000      128         6.70          silver
#
#                                                Title  Price    Brand  Rating  \
# 0  a70 dual sim starlish black 4gb ram 256gb 4g -...   4299     itel     4.2
# 1  x7a dual sim midnight black 4gb ram 128gb 4g l...   4875    honor     4.3
# 2  x9b dual sim 5g midnight black 12gb ram 256gb ...  13550    honor     4.4
# 3  galaxy a15 dual sim blue black 8gb ram 256gb 4...   8666  samsung     4.3
# 4  galaxy a05s dual sim silver 4gb ram 128gb 4g l...   5799  samsung     4.2
#
#    ... Secondary Camera Resolution Refresh Rates       os os_version  \
# 0  ...                         8.0           NaN      NaN        NaN
# 1  ...                         8.0           NaN  android         12
# 2  ...                        16.0           NaN  android        NaN
# 3  ...                        13.0          90.0  android        NaN
# 4  ...                         2.0          90.0  android        NaN
#
#    Processor Speed  Network Type  Model Year Display Resolution  site  \
# 0              NaN            4g         NaN                NaN  noon
# 1              2.3            4g      2023.0           720x1600  noon
# 2              2.0            5g      2023.0                NaN  noon
# 3              NaN            4g      2023.0                NaN  noon
# 4              NaN            4g         NaN          1080x2400  noon
#
#         category
# 0  mobile phones
# 1  mobile phones
# 2  mobile phones
# 3  mobile phones
# 4  mobile phones
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         212 non-null    datetime64[ns]
#  1   ram                          212 non-null    int64
#  2   Battery Size                 212 non-null    int64
#  3   storage                      212 non-null    int64
#  4   Screen Size                  212 non-null    float64
#  5   Colour Name                  212 non-null    object
#  6   Title                        212 non-null    object
#  7   Price                        212 non-null    int64
#  8   Brand                        212 non-null    object
#  9   Rating                       208 non-null    float64
#  10  Product Image                212 non-null    object
#  11  Product Link                 212 non-null    object
#  12  Version                      211 non-null    object
#  13  Model Name                   212 non-null    object
#  14  Primary Camera (MP)          135 non-null    float64
#  15  Secondary Camera Resolution  142 non-null    float64
#  16  Refresh Rates                85 non-null     float64
#  17  os                           159 non-null    object
#  18  os_version                   61 non-null     object
#  19  Processor Speed              62 non-null     float64
#  20  Network Type                 166 non-null    object
#  21  Model Year                   124 non-null    float64
#  22  Display Resolution           66 non-null     object
#  23  site                         212 non-null    object
#  24  category                     212 non-null    object
# dtypes: datetime64[ns](1), float64(7), int64(4), object(13)
# memory usage: 41.5+ KB

# %% [markdown]
# # upload transformed data

# %%
# blob details
blob_name = f"Transformed/noon_transformed{today}.csv"  # File in 'Transformed' folder

# Create a BlobClient
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

# Upload the file
with open(local_file_path, "rb") as data:
    blob_client.upload_blob(data)

print(f"File {local_file_path} uploaded to container '{container_name}' under '{blob_name}'")
# Out:
# File /content/noon_raw2024-10-20 03:33:00.csv uploaded to container 'proj' under 'Transformed/noon_transformed2024-10-20 03:33:00.csv'

# %% [markdown]
# # Data Modeling

# %% [markdown]
# ## Creating Dimensions and Fact Table

# %%
# import pandas as pd
# import numpy as np
# import hashlib
# from azure.storage.blob import BlobServiceClient
# import os


# # Step : Create a function to generate a unique product_id using hashlib
# def generate_product_id(row):
#     # Combine columns to create a unique string
#     unique_string = (str(row['Model Name']) +
#                      str(row['Brand']) +
#                      str(row['Network Type']) +
#                      str(row['ram']) +
#                      str(row['storage']))
#     return hashlib.md5(unique_string.encode()).hexdigest()

# # Apply the function to generate product_id
# df['product_id'] = df.apply(generate_product_id, axis=1)

# # Step 3: Create unique dates and Dim_Date table
# unique_dates = df['date'].drop_duplicates().reset_index(drop=True)
# dim_date = pd.DataFrame({
#     'Date_ID': np.arange(len(unique_dates)),  # Create Date_ID
#     'Date': unique_dates,
#     'Day': unique_dates.dt.day,
#     'Month': unique_dates.dt.month,
#     'Year': unique_dates.dt.year
# })

# # Merge to add Date_ID to the original dataframe
# df = df.merge(dim_date[['Date_ID', 'Date']], left_on='date', right_on='Date', how='left', suffixes=('', '_dim'))

# # Step 4: Fact Table
# fact_table = pd.DataFrame({
#     'product_id': df['product_id'],  # Using the generated product_id
#     'site_id': 1,  # Placeholder; you should have a mapping for site_id
#     'date_id': df['Date_ID'],  # Using Date_ID from Dim_Date
#     'price_EGP': df['Price'],
#     'rating_avg': df['Rating']
# })


# # Create the 'Model' directory if it doesn't exist
# os.makedirs('Model', exist_ok=True)
# # Save Fact Table as Parquet
# fact_table.to_parquet('Model/fact_table.parquet')




# # Step 5: Dim_DeviceSpecifications Table
# dim_device_spec = df[['Battery Size','Screen Size', 'Colour Name',
#        'Title', 'Product Image', 'Product Link',
#        'Version', 'Primary Camera (MP)',
#        'Secondary Camera Resolution', 'Refresh Rates', 'os', 'os_version',
#        'Processor Speed', 'Model Year', 'Display Resolution',
#        'site', 'category']].copy()
# dim_device_spec['product_id'] = df['product_id']  # Use the generated product_id

# # Step 6: Create Dim_Map_ID Table
# dim_map_id = df[['product_id', 'storage', 'ram', 'Brand', 'Model Name', 'Network Type']].copy()

# # Save Dim_Map_ID as Parquet
# dim_map_id.to_parquet('Model/dim_map_id.parquet')

# # Save Dim_DeviceSpecifications as Parquet
# dim_device_spec.to_parquet('Model/dim_device_specifications.parquet')

# # Step 7: Dim_Site Table
# dim_site = df[['site']].drop_duplicates().reset_index(drop=True)
# dim_site['site_id'] = dim_site.index
# dim_site.columns = ['site_name', 'site_id']

# # Save Dim_Site as Parquet
# dim_site.to_parquet('Model/dim_site.parquet')

# # Step 9: Save Dim_Date as Parquet
# dim_date.to_parquet('Model/dim_date.parquet')

# # Step 10: Upload all Parquet files to Azure Blob Storage

# ## Loop through the parquet files in the Model directory and upload them
# model_dir = 'Model'
# for filename in os.listdir(model_dir):
#     local_file_path = os.path.join(model_dir, filename)

#     # Check if it's a file before uploading
#     if os.path.isfile(local_file_path):
#         blob_name = f'Model/{filename}'

#         blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

#         # Upload the file
#         with open(local_file_path, "rb") as data:
#             blob_client.upload_blob(data, overwrite=True)

#         print(f"File {filename} uploaded to container '{container_name}' under '{blob_name}'")

# %% [markdown]
# # Updating

# %%
import pandas as pd
import numpy as np
import hashlib
from azure.storage.blob import BlobServiceClient
import os
from io import BytesIO

# Function to download existing data from Azure Blob Storage
def download_blob_as_df(blob_service_client, container_name, blob_name):
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    try:
        # Download blob to a DataFrame
        with open("temp.parquet", "wb") as download_file:
            download_file.write(blob_client.download_blob().readall())
        return pd.read_parquet("temp.parquet")
    except:
        # Return an empty DataFrame if the blob doesn't exist
        return pd.DataFrame()

# Load the newly scraped dataset
df_new = df
# Convert the 'date' column to datetime format
df_new['date'] = pd.to_datetime(df_new['date'], errors='coerce')

# Step 1: Update Dim_Date
# Create unique dates and Dim_Date table for the new data
unique_dates = df_new['date'].drop_duplicates().reset_index(drop=True)
dim_date_new = pd.DataFrame({
    'Date_ID': np.arange(len(unique_dates)),
    'Date': unique_dates,
    'Day': unique_dates.dt.day,
    'Month': unique_dates.dt.month,
    'Year': unique_dates.dt.year
})

# Download existing Dim_Date from Azure Blob Storage
dim_date_existing = download_blob_as_df(blob_service_client, container_name, "Model/dim_date.parquet")

# Combine new dates with existing dates
if not dim_date_existing.empty:
    dim_date_updated = pd.concat([dim_date_existing, dim_date_new], ignore_index=True).drop_duplicates(subset=['Date'])
else:
    dim_date_updated = dim_date_new


# Reorder to keep the original Date_ID order
dim_date_updated = dim_date_updated.sort_values('Date_ID').reset_index(drop=True)


# Ensure the 'Model' directory exists
if not os.path.exists('Model'):
    os.makedirs('Model')

# Now save the updated Dim_Date table
dim_date_updated.to_parquet('Model/dim_date.parquet')

# Upload updated Dim_Date to Azure Blob Storage
blob_client = blob_service_client.get_blob_client(container=container_name, blob="Model/dim_date.parquet")
with open("Model/dim_date.parquet", "rb") as data:
    blob_client.upload_blob(data, overwrite=True)

print("Dim_Date updated and uploaded successfully.")
# Merge the new dataset (df_new) with the updated dim_date to get Date_ID in df_new
df_new = df_new.merge(dim_date_updated[['Date_ID', 'Date']], left_on='date', right_on='Date', how='left', suffixes=('', '_dim'))

# Function to generate product_id using hashlib
def generate_product_id(row):
    # Combine columns to create a unique string
    unique_string = (str(row['Model Name']) +
                     str(row['Brand']) +
                     str(row['Network Type']) +
                     str(row['ram']) +
                     str(row['storage']))
    return hashlib.md5(unique_string.encode()).hexdigest()


# Apply the function to generate product_id for new data
df_new['product_id'] = df_new.apply(generate_product_id, axis=1)

# Step 2: Update Dim_Site
dim_site_existing = download_blob_as_df(blob_service_client, container_name, "Model/dim_site.parquet")
dim_site_new = df_new[['site']].drop_duplicates().reset_index(drop=True)
dim_site_new['site_id'] = dim_site_new.index
dim_site_new.columns = ['site_name', 'site_id']

if not dim_site_existing.empty:
    dim_site_updated = pd.concat([dim_site_existing, dim_site_new], ignore_index=True).drop_duplicates(subset=['site_name'])
else:
    dim_site_updated = dim_site_new

dim_site_updated = dim_site_updated.sort_values('site_id').reset_index(drop=True)

# Save the updated Dim_Site table
dim_site_updated.to_parquet('Model/dim_site.parquet')

# Upload updated Dim_Site to Azure Blob Storage
blob_client = blob_service_client.get_blob_client(container=container_name, blob="Model/dim_site.parquet")
with open("Model/dim_site.parquet", "rb") as data:
    blob_client.upload_blob(data, overwrite=True)


# Step 2: Download existing fact_table from Azure
fact_table_existing = download_blob_as_df(blob_service_client, container_name, "Model/fact_table.parquet")

# Merge new and existing data for Fact Table
if not fact_table_existing.empty:
    fact_table_existing.set_index('product_id', inplace=True)
    fact_table_new = pd.DataFrame({
        'product_id': df_new['product_id'],
        'site_id': 2,  # Assuming site_id is constant or unchanged
        'date_id': df_new['Date_ID'],  # Use Date_ID generated above
        'price_EGP': df_new['Price'],
        'rating_avg': df_new['Rating']
    })
    fact_table_new.set_index('product_id', inplace=True)

    # Update existing records, and append new ones
    fact_table_updated = fact_table_existing.combine_first(fact_table_new)
else:
    fact_table_updated = pd.DataFrame({
        'product_id': df_new['product_id'],
        'site_id': 1,
        'date_id': df_new['Date_ID'],
        'price_EGP': df_new['Price'],
        'rating_avg': df_new['Rating']
    })

# Step 3: Save the updated Fact Table
fact_table_updated.reset_index(inplace=True)
fact_table_updated.to_parquet('Model/fact_table.parquet')

# Upload updated Fact Table to Azure Blob Storage
blob_client = blob_service_client.get_blob_client(container=container_name, blob="Model/fact_table.parquet")
with open("Model/fact_table.parquet", "rb") as data:
    blob_client.upload_blob(data, overwrite=True)

# Step 4: Update Dim_DeviceSpecifications
dim_device_spec_existing = download_blob_as_df(blob_service_client, container_name, "Model/dim_device_specifications.parquet")
dim_device_spec_new = df_new[['product_id', 'Battery Size','Screen Size', 'Colour Name',  # Include 'product_id' here
        'Title', 'Product Image', 'Product Link',
        'Version', 'Primary Camera (MP)',
        'Secondary Camera Resolution', 'Refresh Rates', 'os', 'os_version',
        'Processor Speed', 'Model Year', 'Display Resolution',
        'site', 'category']]

if not dim_device_spec_existing.empty:
    dim_device_spec_existing.set_index('product_id', inplace=True)
    dim_device_spec_new.set_index('product_id', inplace=True)
    dim_device_spec_updated = dim_device_spec_existing.combine_first(dim_device_spec_new)
else:
    dim_device_spec_updated = dim_device_spec_new

# Save the updated Dim_DeviceSpecifications table
dim_device_spec_updated.reset_index(inplace=True)
dim_device_spec_updated.to_parquet('Model/dim_device_specifications.parquet')

# Upload updated Dim_DeviceSpecifications to Azure Blob Storage
blob_client = blob_service_client.get_blob_client(container=container_name, blob="Model/dim_device_specifications.parquet")
with open("Model/dim_device_specifications.parquet", "rb") as data:
    blob_client.upload_blob(data, overwrite=True)

# Step 5: Update Dim_Map_ID
dim_map_id_existing = download_blob_as_df(blob_service_client, container_name, "Model/dim_map_id.parquet")
dim_map_id_new = df_new[['product_id', 'storage', 'ram', 'Brand', 'Model Name', 'Network Type']]

if not dim_map_id_existing.empty:
    dim_map_id_existing.set_index('product_id', inplace=True)
    dim_map_id_new.set_index('product_id', inplace=True)
    dim_map_id_combined = pd.concat([dim_map_id_existing, dim_map_id_new], ignore_index=False)

    # Drop duplicates based on 'product_id' to ensure unique entries
    dim_map_id_updated = dim_map_id_combined[~dim_map_id_combined.index.duplicated(keep='first')]
else:
    dim_map_id_updated = dim_map_id_new.drop_duplicates(subset=['product_id'])

# Save the updated Dim_Map_ID table
dim_map_id_updated.reset_index(inplace=True)
dim_map_id_updated.to_parquet('Model/dim_map_id.parquet')

# Upload updated Dim_Map_ID to Azure Blob Storage
blob_client = blob_service_client.get_blob_client(container=container_name, blob="Model/dim_map_id.parquet")
with open("Model/dim_map_id.parquet", "rb") as data:
    blob_client.upload_blob(data, overwrite=True)




print("Data processing and upload to Azure Blob Storage completed successfully!")
# Out:
# Data processing and upload to Azure Blob Storage completed successfully!
